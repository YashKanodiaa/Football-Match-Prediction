# %%
import pandas as pd

# %%
matches = pd.read_csv("matches.csv", index_col=0)

# %%
matches.head()
# Out:
#          Date   Time            Comp        Round  Day Venue Result   GF   GA  \
# 1  2023-08-12  12:30  Premier League  Matchweek 1  Sat  Home      W  2.0  1.0
# 2  2023-08-21  20:00  Premier League  Matchweek 2  Mon  Away      W  1.0  0.0
# 3  2023-08-26  15:00  Premier League  Matchweek 3  Sat  Home      D  2.0  2.0
# 4  2023-09-03  16:30  Premier League  Matchweek 4  Sun  Home      W  3.0  1.0
# 5  2023-09-17  16:30  Premier League  Matchweek 5  Sun  Away      W  1.0  0.0
#
#           Opponent  ...  Match Report  Notes    Sh  SoT  Dist   FK PK PKatt  \
# 1  Nott'ham Forest  ...  Match Report    NaN  15.0  7.0  19.1  0.0  0     0
# 2   Crystal Palace  ...  Match Report    NaN  13.0  2.0  16.4  0.0  1     1
# 3           Fulham  ...  Match Report    NaN  18.0  9.0  13.8  0.0  1     1
# 4   Manchester Utd  ...  Match Report    NaN  17.0  5.0  15.0  0.0  0     0
# 5          Everton  ...  Match Report    NaN  13.0  4.0  17.4  0.0  0     0
#
#    Season     Team
# 1    2024  Arsenal
# ...

# %%
matches.shape
# Out:
# (3710, 27)

# %%
38*20*5
# Out:
# 3800

# %%
matches["Team"].value_counts()
# Out:
# Arsenal                     186
# West Ham United             186
# Everton                     186
# Liverpool                   186
# Wolverhampton Wanderers     186
# Crystal Palace              186
# Aston Villa                 186
# Newcastle United            185
# Manchester United           185
# Manchester City             184
# Chelsea                     184
# Brighton and Hove Albion    184
# Tottenham Hotspur           184
# Leicester City              152
# Southampton                 152
# Burnley                     148
# Leeds United                114
# Fulham                      110
# Sheffield United            110
# Bournemouth                 110
# Brentford                   110
# Watford                      76
# Norwich City                 76
# Nottingham Forest            72
# West Bromwich Albion         38
# Luton Town                   34
# Name: Team, dtype: int64

# %%
matches["Round"].value_counts()
# Out:
# Matchweek 1     100
# Matchweek 17    100
# Matchweek 33    100
# Matchweek 32    100
# Matchweek 31    100
# Matchweek 30    100
# Matchweek 28    100
# Matchweek 27    100
# Matchweek 25    100
# Matchweek 24    100
# Matchweek 23    100
# Matchweek 22    100
# Matchweek 21    100
# Matchweek 2     100
# Matchweek 19    100
# Matchweek 18    100
# Matchweek 20    100
# Matchweek 16    100
# Matchweek 8     100
# Matchweek 3     100
# Matchweek 4     100
# Matchweek 5     100
# Matchweek 6     100
# Matchweek 15    100
# Matchweek 7     100
# Matchweek 9     100
# Matchweek 10    100
# Matchweek 11    100
# Matchweek 12    100
# Matchweek 13    100
# Matchweek 14    100
# Matchweek 26     98
# Matchweek 29     98
# Matchweek 34     94
# Matchweek 35     80
# Matchweek 36     80
# Matchweek 37     80
# Matchweek 38     80
# Name: Round, dtype: int64

# %%
matches.dtypes
# Out:
# Date             object
# Time             object
# Comp             object
# Round            object
# Day              object
# Venue            object
# Result           object
# GF              float64
# GA              float64
# Opponent         object
# xG              float64
# xGA             float64
# Poss            float64
# Attendance      float64
# Captain          object
# Formation        object
# Referee          object
# Match Report     object
# Notes           float64
# Sh              float64
# SoT             float64
# Dist            float64
# FK              float64
# PK                int64
# PKatt             int64
# Season            int64
# Team             object
# dtype: object

# %%
#converting date from object data type to date time data type
matches["Date"] = pd.to_datetime(matches["Date"])

# %%
'''converting venue from object data type to numeric, by converting it from object to category and then category to
numeric data type'''
matches["Venue_code"] = matches["Venue"].astype("category").cat.codes

# %%
#converting opponent from object to numeric data type in a similar way to venue
#by giving a unique code to each opponent
matches["Opp_code"] = matches["Opponent"].astype("category").cat.codes

# %%
#coverting time to only hours
#regex is regular expression, replacing ':' with nothing
matches["Hour"] = matches["Time"].str.replace(":.+", "", regex=True).astype("int")

# %%
#converting date from object to numeric by assigning unique code to each day
matches["Day_code"] = matches["Date"].dt.dayofweek

# %%
#this returns boolean value but after adding astype it will return a integer value
matches["Target"] = (matches["Result"] == "W").astype("int")

# %%
matches
# Out:
#          Date   Time            Comp         Round  Day Venue Result   GF  \
# 1  2023-08-12  12:30  Premier League   Matchweek 1  Sat  Home      W  2.0
# 2  2023-08-21  20:00  Premier League   Matchweek 2  Mon  Away      W  1.0
# 3  2023-08-26  15:00  Premier League   Matchweek 3  Sat  Home      D  2.0
# 4  2023-09-03  16:30  Premier League   Matchweek 4  Sun  Home      W  3.0
# 5  2023-09-17  16:30  Premier League   Matchweek 5  Sun  Away      W  1.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 38 2020-07-07  18:00  Premier League  Matchweek 34  Tue  Away      L  1.0
# 39 2020-07-11  12:30  Premier League  Matchweek 35  Sat  Home      L  0.0
# 40 2020-07-14  20:15  Premier League  Matchweek 36  Tue  Away      L  0.0
# 41 2020-07-18  17:30  Premier League  Matchweek 37  Sat  Home      L  0.0
# 42 2020-07-26  16:00  Premier League  Matchweek 38  Sun  Away      L  0.0
#
#      GA         Opponent  ...   FK  PK  PKatt  Season          Team  \
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
#RandomForest is a type of ML model that can pick up non-linearity from a data that a linear model cannot pick

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = matches[matches["Date"] < '2024-01-01']

# %%
test = matches[matches["Date"] > '2024-01-01']

# %%
predictors = ["Venue_code", "Opp_code", "Hour", "Day_code"]

# %%
rf.fit(train[predictors], train["Target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test["Target"], preds)

# %%
acc
# Out:
# 0.6557971014492754

# %%
combined = pd.DataFrame(dict(actual=test["Target"], predicted=preds))

# %%
pd.crosstab(index=combined["actual"], columns=combined["predicted"])
# Out:
# predicted    0   1
# actual
# 0          146  30
# 1           65  35

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test["Target"], preds)
# Out:
# 0.5384615384615384

# %%
grouped_matches = matches.groupby("Team")

# %%
group = grouped_matches.get_group("Manchester City")

# %%
group
# Out:
#          Date   Time            Comp         Round  Day Venue Result   GF  \
# 1  2023-08-11  20:00  Premier League   Matchweek 1  Fri  Away      W  3.0
# 3  2023-08-19  20:00  Premier League   Matchweek 2  Sat  Home      W  1.0
# 4  2023-08-27  14:00  Premier League   Matchweek 3  Sun  Away      W  2.0
# 5  2023-09-02  15:00  Premier League   Matchweek 4  Sat  Home      W  5.0
# 6  2023-09-16  15:00  Premier League   Matchweek 5  Sat  Away      W  3.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 51 2020-07-08  18:00  Premier League  Matchweek 34  Wed  Home      W  5.0
# 52 2020-07-11  20:00  Premier League  Matchweek 35  Sat  Away      W  5.0
# 53 2020-07-15  18:00  Premier League  Matchweek 36  Wed  Home      W  2.0
# 55 2020-07-21  18:00  Premier League  Matchweek 37  Tue  Away      W  4.0
# 56 2020-07-26  16:00  Premier League  Matchweek 38  Sun  Home      W  5.0
#
#      GA       Opponent  ...   FK  PK  PKatt  Season             Team  \
# ...

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("Date")
    rolling_stats = group[cols].rolling(3, closed = 'left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset = new_cols)
    return group

# %%
cols = ["GF", "GA", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]
new_cols = [f"{c}_rolling" for c in cols]

# %%
new_cols
# Out:
# ['GF_rolling',
#  'GA_rolling',
#  'Sh_rolling',
#  'SoT_rolling',
#  'Dist_rolling',
#  'FK_rolling',
#  'PK_rolling',
#  'PKatt_rolling']

# %%
rolling_averages(group, cols, new_cols)
# Out:
#          Date   Time            Comp         Round  Day Venue Result   GF  \
# 4  2019-08-31  15:00  Premier League   Matchweek 4  Sat  Home      W  4.0
# 5  2019-09-14  17:30  Premier League   Matchweek 5  Sat  Away      L  2.0
# 7  2019-09-21  15:00  Premier League   Matchweek 6  Sat  Home      W  8.0
# 9  2019-09-28  17:30  Premier League   Matchweek 7  Sat  Away      W  3.0
# 11 2019-10-06  14:00  Premier League   Matchweek 8  Sun  Home      L  0.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 41 2024-03-10  15:45  Premier League  Matchweek 28  Sun  Away      D  1.0
# 43 2024-03-31  16:30  Premier League  Matchweek 30  Sun  Home      D  0.0
# 44 2024-04-03  20:15  Premier League  Matchweek 31  Wed  Home      W  4.0
# 45 2024-04-06  12:30  Premier League  Matchweek 32  Sat  Away      W  4.0
# 47 2024-04-13  15:00  Premier League  Matchweek 33  Sat  Home      W  5.0
#
#      GA        Opponent  ...  Day_code  Target  GF_rolling  GA_rolling  \
# ...

# %%
matches_rolling = matches.groupby("Team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
#matches_rolling

# %%
matches_rolling = matches_rolling.droplevel('Team')

# %%
#matches_rolling

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
#matches_rolling

# %%
def make_predictions(data, predictors):
    train = data[data["Date"] < '2022-01-01']
    test = data[data["Date"] > '2022-01-01']
    rf.fit(train[predictors], train["Target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["Target"], predicted=preds), index=test.index)
    error = precision_score(test["Target"], preds)
    return combined, error

# %%
combined, error = make_predictions(matches_rolling, predictors + new_cols)

# %%
error
# Out:
# 0.5686274509803921

# %%
combined
# Out:
#       actual  predicted
# 93         0          1
# 94         1          0
# 95         1          0
# 96         1          1
# 97         1          1
# ...      ...        ...
# 3624       0          0
# 3625       0          0
# 3626       0          0
# 3627       0          0
# 3628       0          0
#
# [1812 rows x 2 columns]

# %%
combined = combined.merge(matches_rolling[["Date", "Team", "Opponent", "Result"]], left_index=True, right_index=True)

# %%
combined
# Out:
#       actual  predicted       Date                     Team         Opponent  \
# 93         0          1 2022-01-23                  Arsenal          Burnley
# 94         1          0 2022-02-10                  Arsenal           Wolves
# 95         1          0 2022-02-19                  Arsenal        Brentford
# 96         1          1 2022-02-24                  Arsenal           Wolves
# 97         1          1 2022-03-06                  Arsenal          Watford
# ...      ...        ...        ...                      ...              ...
# 3624       0          0 2024-04-02  Wolverhampton Wanderers          Burnley
# 3625       0          0 2024-04-06  Wolverhampton Wanderers         West Ham
# 3626       0          0 2024-04-13  Wolverhampton Wanderers  Nott'ham Forest
# 3627       0          0 2024-04-20  Wolverhampton Wanderers          Arsenal
# 3628       0          0 2024-04-24  Wolverhampton Wanderers      Bournemouth
#
#      Result
# 93        D
# 94        W
# ...

# %%
class MissingDict(dict):
    __missing__=lambda self, key: key
    
map_values = {"Brighton and Hove Albion": "Brighton", "Manchester United": "Manchester Utd",
              "Newcastle United": "Newcastle Utd", "Tottenham Hotspur": "Tottenham", "West Ham United": "West Ham",
              "Wolverhampton Wanderers": "Wolves"} 
mapping = MissingDict(**map_values)

# %%
mapping["West Ham United"]
# Out:
# 'West Ham'

# %%
combined["New_Team"] = combined["Team"].map(mapping)

# %%
combined
# Out:
#       actual  predicted       Date                     Team         Opponent  \
# 93         0          1 2022-01-23                  Arsenal          Burnley
# 94         1          0 2022-02-10                  Arsenal           Wolves
# 95         1          0 2022-02-19                  Arsenal        Brentford
# 96         1          1 2022-02-24                  Arsenal           Wolves
# 97         1          1 2022-03-06                  Arsenal          Watford
# ...      ...        ...        ...                      ...              ...
# 3624       0          0 2024-04-02  Wolverhampton Wanderers          Burnley
# 3625       0          0 2024-04-06  Wolverhampton Wanderers         West Ham
# 3626       0          0 2024-04-13  Wolverhampton Wanderers  Nott'ham Forest
# 3627       0          0 2024-04-20  Wolverhampton Wanderers          Arsenal
# 3628       0          0 2024-04-24  Wolverhampton Wanderers      Bournemouth
#
#      Result New_Team
# 93        D  Arsenal
# ...

# %%
merged = combined.merge(combined, left_on=["Date", "New_Team"], right_on=["Date", "Opponent"])

# %%
merged
# Out:
#       actual_x  predicted_x       Date                   Team_x  \
# 0            0            1 2022-01-23                  Arsenal
# 1            1            0 2022-02-10                  Arsenal
# 2            1            0 2022-02-19                  Arsenal
# 3            1            1 2022-02-24                  Arsenal
# 4            1            1 2022-03-06                  Arsenal
# ...        ...          ...        ...                      ...
# 1698         0            0 2024-04-02  Wolverhampton Wanderers
# 1699         0            0 2024-04-06  Wolverhampton Wanderers
# 1700         0            0 2024-04-13  Wolverhampton Wanderers
# 1701         0            0 2024-04-20  Wolverhampton Wanderers
# 1702         0            0 2024-04-24  Wolverhampton Wanderers
#
#            Opponent_x Result_x New_Team_x  actual_y  predicted_y  \
# 0             Burnley        D    Arsenal         0            0
# ...

# %%
merged[(merged["predicted_x"] ==1) & (merged["predicted_y"] ==0)]["actual_x"].value_counts()
# Out:
# 1    206
# 0    140
# Name: actual_x, dtype: int64
